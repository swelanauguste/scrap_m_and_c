# %%
import pandas as pd

# %%
df = pd.read_csv('../massy1.csv')
df.columns, df.shape
# Out:
# (Index(['name', 'price', 'category', 'ul', 'img'], dtype='object'), (3481, 5))

# %%
df
# Out:
#                                             name    price       category  \
# 0                               Blue Waters 1.5L    $2.50   grocery-food
# 1                              Blue Waters 710ML    $1.40   grocery-food
# 2                   Nissin Top Ramen Chicken 85G    $2.49   grocery-food
# 3               Forest Spring Mineral Water 1.5L    $3.25   grocery-food
# 4                 Seabelle Tuna Fish In Oil 200G    $5.90   grocery-food
# ...                                          ...      ...            ...
# 3476  Francis Fish Frozen Dorado Fillet (per KG)   $64.33  meats-seafood
# 3477  Francis Fish Frozen Dorado Steaks (per KG)   $61.71  meats-seafood
# 3478    Dg Season Chicken Breast Strips (per KG)   $36.92  meats-seafood
# 3479                Imported Picnic Ham (Per Kg)   $27.99  meats-seafood
# 3480                  Chicken Leg Whole (per KG)  $114.80  meats-seafood
#
#                                                      ul  \
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#                                             name    price       category  \
# 0                               Blue Waters 1.5L    $2.50   grocery-food
# 1                              Blue Waters 710ML    $1.40   grocery-food
# 2                   Nissin Top Ramen Chicken 85G    $2.49   grocery-food
# 3               Forest Spring Mineral Water 1.5L    $3.25   grocery-food
# 4                 Seabelle Tuna Fish In Oil 200G    $5.90   grocery-food
# ...                                          ...      ...            ...
# 3476  Francis Fish Frozen Dorado Fillet (per KG)   $64.33  meats-seafood
# 3477  Francis Fish Frozen Dorado Steaks (per KG)   $61.71  meats-seafood
# 3478    Dg Season Chicken Breast Strips (per KG)   $36.92  meats-seafood
# 3479                Imported Picnic Ham (Per Kg)   $27.99  meats-seafood
# 3480                  Chicken Leg Whole (per KG)  $114.80  meats-seafood
#
#                                                      ul  \
# ...

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (3338, 5)

# %%
df['supplier']=df['supplier'].str.strip()

# %%
df
# df.to_csv('massy_cleaned_1.csv', index=False)
# Out:
#                                             name    price       category  \
# 0                               Blue Waters 1.5L    $2.50   grocery-food
# 1                              Blue Waters 710ML    $1.40   grocery-food
# 2                   Nissin Top Ramen Chicken 85G    $2.49   grocery-food
# 3               Forest Spring Mineral Water 1.5L    $3.25   grocery-food
# 4                 Seabelle Tuna Fish In Oil 200G    $5.90   grocery-food
# ...                                          ...      ...            ...
# 3476  Francis Fish Frozen Dorado Fillet (per KG)   $64.33  meats-seafood
# 3477  Francis Fish Frozen Dorado Steaks (per KG)   $61.71  meats-seafood
# 3478    Dg Season Chicken Breast Strips (per KG)   $36.92  meats-seafood
# 3479                Imported Picnic Ham (Per Kg)   $27.99  meats-seafood
# 3480                  Chicken Leg Whole (per KG)  $114.80  meats-seafood
#
#                                                      ul  \
# ...

# %%
df.to_csv('massy_cleaned_1.csv', index=False)

# %%
df['supplier'] = 'm&c'

# %%
df
# Out:
#                                                    name    price  \
# 0       Energizer Battery Aa 4pk 1 Each EPR01132 E91BP4   $21.12
# 1     Dap Fast Dry Acrylic Latex Caulk 10.01oz 1 Eac...   $14.94
# 2                  Toledo T-lock Entry 1 Each T-T871US5   $38.43
# 3                         Hinge 4x3x3 Inch 1 Pair SH001   $46.36
# 4     Thoroseal Weatherproof Sealer 35lb 1 Each RSTH...  $258.50
# ...                                                 ...      ...
# 2117                             MAGIC TAPE 3/4X300 3PK   $22.75
# 2118                      NUMBER -7- 4" SATNI PREST M/D   $33.69
# 2119                        Cartel Exit  1 Each VP-EXIT    $9.59
# 2120                         SAFETY GLASSES GRY/CLR 2PK   $28.13
# 2121   Toledo  Laminated Padlock  Black  1 Each T-TB...   $43.57
#
#                                 brand  \
# 0     Electrical Tools &  Accessories
# 1                 Caulks and Sealants
# 2               Door Knobs & Hardware
# ...

# %%
df.to_csv('m&c_cleaned.csv', index=False)
