# %%
import pandas as pd

# %%
df = pd.read_csv('computer_world_clean1.csv')
df.columns, df.shape
# Out:
# (Index(['name', 'price', 'brand', 'url', 'image'], dtype='object'), (996, 5))

# %%
df
# Out:
#                                                   name          price  \
# 0    2h-8b Sketch Pencil Set For Art Drawing, 12pcs...           7.75
# 1    Adjustable Height Office Tall Drafting Chair w...            NaN
# 2    Black Ribbed Office Mid-Back PU Leather Execut...         795.00
# 3    Blue Racing style Gaming Chair Office Chair Co...         895.00
# 4    Chair, Stackable Banquet Blk 1643001BKBK – 999734         245.00
# ..                                                 ...            ...
# 991  Xtech XTC-360 – USB Adapter, Micro USB Male to...          20.00
# 992             XTECH XTC318 6FT USB TO PARALLEL CABLE          65.00
# 993                         XTECH XTF-CD187 Gamer Desk         595.00
# 994  Yellow Multifunction Paper – 75gsm, Available ...  43.00 – 53.00
# 995  ZINGYOU Condenser Microphone Bundle, BM-800 Mi...         295.00
#
#                     brand                                                url  \
# ...

# %%
df['supplier'] = 'computer world'

# %%
df['url']=df['url'].str.lstrip()
df.dropna(inplace=True)
df
# Out:
#                                                   name          price  \
# 0    2h-8b Sketch Pencil Set For Art Drawing, 12pcs...           7.75
# 1    Adjustable Height Office Tall Drafting Chair w...
# 2    Black Ribbed Office Mid-Back PU Leather Execut...         795.00
# 3    Blue Racing style Gaming Chair Office Chair Co...         895.00
# 4    Chair, Stackable Banquet Blk 1643001BKBK – 999734         245.00
# ..                                                 ...            ...
# 991  Xtech XTC-360 – USB Adapter, Micro USB Male to...          20.00
# 992             XTECH XTC318 6FT USB TO PARALLEL CABLE          65.00
# 993                         XTECH XTF-CD187 Gamer Desk         595.00
# 994  Yellow Multifunction Paper – 75gsm, Available ...  43.00 – 53.00
# 995  ZINGYOU Condenser Microphone Bundle, BM-800 Mi...         295.00
#
#                     brand                                                url  \
# ...

# %%
df
# Out:
#                                                   name          price  \
# 0    2h-8b Sketch Pencil Set For Art Drawing, 12pcs...           7.75
# 1    Adjustable Height Office Tall Drafting Chair w...            NaN
# 2    Black Ribbed Office Mid-Back PU Leather Execut...         795.00
# 3    Blue Racing style Gaming Chair Office Chair Co...         895.00
# 4    Chair, Stackable Banquet Blk 1643001BKBK – 999734         245.00
# ..                                                 ...            ...
# 991  Xtech XTC-360 – USB Adapter, Micro USB Male to...          20.00
# 992             XTECH XTC318 6FT USB TO PARALLEL CABLE          65.00
# 993                         XTECH XTF-CD187 Gamer Desk         595.00
# 994  Yellow Multifunction Paper – 75gsm, Available ...  43.00 – 53.00
# 995  ZINGYOU Condenser Microphone Bundle, BM-800 Mi...         295.00
#
#                     brand                                                url  \
# ...

# %%
df.to_csv('computer_world_cleaned.csv', index=False)

# %%
df
# Out:
#                                                   name          price  \
# 0    2h-8b Sketch Pencil Set For Art Drawing, 12pcs...           7.75
# 1    Adjustable Height Office Tall Drafting Chair w...
# 2    Black Ribbed Office Mid-Back PU Leather Execut...         795.00
# 3    Blue Racing style Gaming Chair Office Chair Co...         895.00
# 4    Chair, Stackable Banquet Blk 1643001BKBK – 999734         245.00
# ..                                                 ...            ...
# 991  Xtech XTC-360 – USB Adapter, Micro USB Male to...          20.00
# 992             XTECH XTC318 6FT USB TO PARALLEL CABLE          65.00
# 993                         XTECH XTF-CD187 Gamer Desk         595.00
# 994  Yellow Multifunction Paper – 75gsm, Available ...  43.00 – 53.00
# 995  ZINGYOU Condenser Microphone Bundle, BM-800 Mi...         295.00
#
#                     brand                                                url  \
# ...

# %%
df['supplier'] = 'm&c'

# %%
df
# Out:
#                                                    name    price  \
# 0       Energizer Battery Aa 4pk 1 Each EPR01132 E91BP4   $21.12
# 1     Dap Fast Dry Acrylic Latex Caulk 10.01oz 1 Eac...   $14.94
# 2                  Toledo T-lock Entry 1 Each T-T871US5   $38.43
# 3                         Hinge 4x3x3 Inch 1 Pair SH001   $46.36
# 4     Thoroseal Weatherproof Sealer 35lb 1 Each RSTH...  $258.50
# ...                                                 ...      ...
# 2117                             MAGIC TAPE 3/4X300 3PK   $22.75
# 2118                      NUMBER -7- 4" SATNI PREST M/D   $33.69
# 2119                        Cartel Exit  1 Each VP-EXIT    $9.59
# 2120                         SAFETY GLASSES GRY/CLR 2PK   $28.13
# 2121   Toledo  Laminated Padlock  Black  1 Each T-TB...   $43.57
#
#                                 brand  \
# 0     Electrical Tools &  Accessories
# 1                 Caulks and Sealants
# 2               Door Knobs & Hardware
# ...

# %%
df.to_csv('m&c_cleaned.csv', index=False)
